# %%
import pandas as pd

df1 = pd.read_csv('Data/7_OneCatOneNum.csv')
df1.head()
# Out:
#           Country    Value
# 0   United States  12394.0
# 1          Russia   6148.0
# 2   Germany (FRG)   1653.0
# 3          France   2162.0
# 4  United Kingdom   1214.0

# %%
a = pd.Series([1,2,3], index=['a', 'b', 'c'])
print (a)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = {'A' : [1,2,3],
        "B": [2,3,4]}

df = pd.DataFrame(data, index= ['a', 'b', 'c'])
df
# Out:
#    A  B
# a  1  2
# b  2  3
# c  3  4

# %%
df.info
# Out:
# <bound method DataFrame.info of    A  B
# a  1  2
# b  2  3
# c  3  4>

# %%
df2 = pd.read_csv('Data/10_OneNumSevCatSubgroupsSevObs.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df3 = pd.read_csv("Data/OneCatSeveralNumOrdered.csv")
df3
# Out:
#                 Country     1990     1991     1992     1993     1994     1995  \
# 0         United States  10732.0  12515.0  14132.0  13847.0  11523.0  11216.0
# 1                Russia      NaN      NaN   2605.0   3439.0   1478.0   3889.0
# 2         Germany (FRG)   1816.0   2482.0   1437.0   1500.0   2800.0   1465.0
# 3                France   1712.0   1111.0   1185.0    929.0    851.0    971.0
# 4        United Kingdom   1867.0   1523.0   1180.0   1421.0   1539.0   1475.0
# 5                 China    941.0   1315.0    703.0   1436.0   1111.0   1013.0
# 6          Soviet Union   9777.0   5667.0      NaN      NaN      NaN      NaN
# 7           Netherlands    416.0    455.0    365.0    455.0    627.0    473.0
# 8                 Italy    206.0    349.0    248.0    341.0    208.0    297.0
# 9                Israel     85.0    152.0    324.0    383.0    296.0    166.0
# 10              Ukraine      NaN      NaN    165.0     82.0    236.0    167.0
# ...

# %%
df3.dropna()
# Out:
#                 Country     1990     1991     1992     1993     1994     1995  \
# 0         United States  10732.0  12515.0  14132.0  13847.0  11523.0  11216.0
# 2         Germany (FRG)   1816.0   2482.0   1437.0   1500.0   2800.0   1465.0
# 3                France   1712.0   1111.0   1185.0    929.0    851.0    971.0
# 4        United Kingdom   1867.0   1523.0   1180.0   1421.0   1539.0   1475.0
# 5                 China    941.0   1315.0    703.0   1436.0   1111.0   1013.0
# 7           Netherlands    416.0    455.0    365.0    455.0    627.0    473.0
# 8                 Italy    206.0    349.0    248.0    341.0    208.0    297.0
# 9                Israel     85.0    152.0    324.0    383.0    296.0    166.0
# 11                Spain    108.0    100.0     65.0     98.0    237.0     82.0
# 12               Sweden    231.0    156.0    149.0    103.0    111.0    196.0
# 13          Switzerland    404.0    432.0    396.0    184.0    133.0    139.0
# ...

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit([[32],[56],[84]],[2,6,5])
print (reg.coef_,reg.intercept_)
# Out:
# [0.05511811] 1.173228346456693

# %%
def f(x):
    f = 0.05511811*x + 1.173
    return f

# %%
df = pd.read_csv('Data/10_OneNumSevCatSubgroupsSevObs.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
grouped = df.groupby('sex')
grouped.count()
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Female          87   87      87   87    87    87
# Male           157  157     157  157   157   157
