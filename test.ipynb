# %%
import pandas as pd 

df = pd.read_csv('Assignment-9.png.csv')
# df = df.fillna(0)

# %%
gr1 = ['Software Development' for i in range (6)]
gr2 = ['Product Management']
gr3 = ['Management & Consulting' for i in range (3)]
gr4 = ['Designing']
gr5 = ['Testing']
gr6 = [ 'Infrastructure' for i in range (2)]
gr7 = ['Data, AI & ML']
gr8 = ['Other' for i in range (2)]

gr = gr1 + gr2 + gr3 + gr4 + gr5 + gr6 + gr7 + gr8

df['Group'] = gr
df
# Out:
#                                              Vị trí  Dưới 1 năm  \
# 0                                Back-end Developer        12.0
# 1                               Front-end Developer        11.0
# 2                              Full-stack Developer        17.0
# 3                                  Mobile Developer        12.0
# 4                                    Game Developer        19.0
# 5                                 Embedded Engineer        15.0
# 6   Product Owner/Product Manager/ Business Analyst        12.5
# 7                    Project Manager/Project Leader        19.5
# 8                                   IT Lead/Manager         NaN
# 9                                     IT Consultant         NaN
# 10                                         Designer         NaN
# 11                                  Tester or QA-QC        11.5
# 12                     System Engineer/System Admin        13.0
# 13                                  DevOps Engineer         NaN
# ...

# %% [markdown]
# ## Cách 1 : Dùng biểu đồ lolipop
#
# - Biểu đồ lolipop dùng để biểu diễn mức lương của các vị trí khác nhau, mỗi nhóm vị trí sẽ có một màu khác nhau và mỗi biểu đồ nhỏ là khoảng năm kinh nghiệm
# - Dựa vào từng biểu đồ nhỏ theo năm kinh nghiệm, ta sẽ biết được với cùng số năm kinh nghiệm, từng vị trí sẽ có mức lương bao nhiêu.

# %%
import matplotlib.pyplot as plt 
from matplotlib.pyplot import figure

from matplotlib.lines import Line2D

fig = plt.gcf()
fig.set_size_inches(18, 50)
width = 0.4
plt.subplot(5,1,1)
my_range = range (0, len(df))
plt.hlines(y=df['Vị trí'], xmin=0, xmax=df['Dưới 1 năm'], color=my_color,linewidth=3, alpha =0.8)
plt.scatter(df['Dưới 1 năm'], my_range, color=my_color, s=80, alpha=1)
plt.title("Dưới 1 năm ", fontsize=12, x=0.5,y=1.02, color = 'red')
# plt.xlabel('Lương (triệu)', fontsize=10)
plt.ylabel('',fontsize=20)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
# plt.xticks([])  

custom_lines = [Line2D([0], [0], color="#ffa600", lw=4),
                Line2D([0], [0], color="#f95d6a", lw=4),
                Line2D([0], [0], color="darkcyan", lw=4),
                Line2D([0], [0], color="pink", lw=4),
                Line2D([0], [0], color="green", lw=4),
                Line2D([0], [0], color="purple", lw=4),
                Line2D([0], [0], color="blue", lw=4),
                Line2D([0], [0], color="#a05195", lw=4)]

plt.legend(custom_lines, ['Software Development','Product Management','Management & Consulting','Designing' ,'Testing','Infrastructure','Data, AI & ML','Other'], loc = 'lower right')

plt.grid()

plt.subplot(5,1,2)
plt.hlines(y=df['Vị trí'], xmin=0, xmax=df['Từ 1 đến dưới 3 năm'], color=my_color,linewidth=3, alpha =0.8)
plt.scatter(df['Từ 1 đến dưới 3 năm'], my_range, color=my_color, s=80, alpha=1)
plt.title(" Từ 1 đến dưới 3 năm  ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.ylabel('',fontsize=20)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
custom_lines = [Line2D([0], [0], color="#ffa600", lw=4),
                Line2D([0], [0], color="#f95d6a", lw=4),
                Line2D([0], [0], color="darkcyan", lw=4),
                Line2D([0], [0], color="pink", lw=4),
                Line2D([0], [0], color="green", lw=4),
                Line2D([0], [0], color="purple", lw=4),
                Line2D([0], [0], color="blue", lw=4),
                Line2D([0], [0], color="#a05195", lw=4)]

plt.legend(custom_lines, ['Software Development','Product Management','Management & Consulting','Designing' ,'Testing','Infrastructure','Data, AI & ML','Other'], loc = 'lower right')

plt.grid()

plt.subplot(5,1,3)
plt.hlines(y=df['Vị trí'], xmin=0, xmax=df['Từ 3 đến dưới 5 năm'], color=my_color,linewidth=3, alpha =0.8)
plt.scatter(df['Từ 3 đến dưới 5 năm'], my_range, color=my_color, s=80, alpha=1)
plt.title(" Từ 3 đến dưới 5 năm  ", fontsize=12, x=0.5,y=1.02,color = 'red')
# plt.xlabel('Lương (triệu)', fontsize=10)
plt.ylabel('',fontsize=20)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
custom_lines = [Line2D([0], [0], color="#ffa600", lw=4),
                Line2D([0], [0], color="#f95d6a", lw=4),
                Line2D([0], [0], color="darkcyan", lw=4),
                Line2D([0], [0], color="pink", lw=4),
                Line2D([0], [0], color="green", lw=4),
                Line2D([0], [0], color="purple", lw=4),
                Line2D([0], [0], color="blue", lw=4),
                Line2D([0], [0], color="#a05195", lw=4)]

plt.legend(custom_lines, ['Software Development','Product Management','Management & Consulting','Designing' ,'Testing','Infrastructure','Data, AI & ML','Other'], loc = 'lower right')

plt.grid()

plt.subplot(5,1,4)
plt.hlines(y=df['Vị trí'], xmin=0, xmax=df['Từ 5 đến 8 năm'], color=my_color,linewidth=3, alpha =0.8)
plt.scatter(df['Từ 5 đến 8 năm'], my_range, color=my_color, s=80, alpha=1)
plt.title("Từ 5 đến 8 năm  ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.ylabel('',fontsize=20)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
custom_lines = [Line2D([0], [0], color="#ffa600", lw=4),
                Line2D([0], [0], color="#f95d6a", lw=4),
                Line2D([0], [0], color="darkcyan", lw=4),
                Line2D([0], [0], color="pink", lw=4),
                Line2D([0], [0], color="green", lw=4),
                Line2D([0], [0], color="purple", lw=4),
                Line2D([0], [0], color="blue", lw=4),
                Line2D([0], [0], color="#a05195", lw=4)]

plt.legend(custom_lines, ['Software Development','Product Management','Management & Consulting','Designing' ,'Testing','Infrastructure','Data, AI & ML','Other'], loc = 'lower right')

plt.grid()

plt.subplot(5,1,5)

plt.hlines(y=df['Vị trí'], xmin=0, xmax=df['Trên 8 năm'], color=my_color,linewidth=3, alpha =0.8)
plt.scatter(df['Trên 8 năm'], my_range, color=my_color, s=80, alpha=1)
plt.title(" Trên 8 năm	  ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xlabel('Lương (triệu)', fontsize=10)
plt.ylabel('',fontsize=20)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
custom_lines = [Line2D([0], [0], color="#ffa600", lw=4),
                Line2D([0], [0], color="#f95d6a", lw=4),
                Line2D([0], [0], color="darkcyan", lw=4),
                Line2D([0], [0], color="pink", lw=4),
                Line2D([0], [0], color="green", lw=4),
                Line2D([0], [0], color="purple", lw=4),
                Line2D([0], [0], color="blue", lw=4),
                Line2D([0], [0], color="#a05195", lw=4)]

plt.legend(custom_lines, ['Software Development','Product Management','Management & Consulting','Designing' ,'Testing','Infrastructure','Data, AI & ML','Other'], loc = 'lower right')

plt.grid()
fig.savefig('lolipop.png', dpi=400)
# Out:
# /var/folders/cs/8r3m5sjs0rd7ts526sxtp81c0000gn/T/ipykernel_14741/1184572515.py:115: UserWarning: Glyph 9 (	) missing from current font.
#   fig.savefig('lolipop.png', dpi=400)
# /Users/thutranghoa/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /Users/thutranghoa/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np 
my_color=np.where(df['Group']=='Software Development',"#ffa600",
                  np.where(df['Group']=='Product Management',"#f95d6a",
                   np.where(df['Group']=='Management & Consulting',"darkcyan",
                    np.where(df['Group']=='Designing',"pink",
                    np.where(df['Group']=='Testing',"green",
                    np.where(df['Group']=='Infrastructure',"purple",
                    np.where(df['Group']=='Data, AI & ML',"blue",
                    "#a05195")))))))

# %%
import matplotlib.pyplot as plt
my_range = range (0, len(df))
plt.hlines(y=df['Vị trí'], xmin=0, xmax=df['Dưới 1 năm'], color=my_color,linewidth=3, alpha =0.8)
plt.scatter(df['Dưới 1 năm'], my_range, color=my_color, s=80, alpha=1)
plt.title("Dưới 1 năm ", fontsize=12, x=0.5,y=1.02, color = 'red')
plt.xlabel('Lương (triệu)', fontsize=10)
plt.ylabel('',fontsize=20)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

# plt.legend( ['Software Development','Product Management','Management & Consulting','Designing' ,'Testing','Infrastructure','Data, AI & ML','Other'])

plt.grid()

# %%
import matplotlib.pyplot as plt
my_range = range (0, len(df))
plt.hlines(y=df['Vị trí'], xmin=0, xmax=df['Từ 1 đến dưới 3 năm'], color=my_color,linewidth=3, alpha =0.8)
plt.scatter(df['Từ 1 đến dưới 3 năm'], my_range, color=my_color, s=80, alpha=1)
plt.title(" Từ 1 đến dưới 3 năm  ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xlabel('Lương (triệu)', fontsize=10)
plt.ylabel('',fontsize=20)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
custom_lines = [Line2D([0], [0], color="#ffa600", lw=4),
                Line2D([0], [0], color="#f95d6a", lw=4),
                Line2D([0], [0], color="darkcyan", lw=4),
                Line2D([0], [0], color="pink", lw=4),
                Line2D([0], [0], color="green", lw=4),
                Line2D([0], [0], color="purple", lw=4),
                Line2D([0], [0], color="blue", lw=4),
                Line2D([0], [0], color="#a05195", lw=4)]

plt.legend(custom_lines, ['Software Development','Product Management','Management & Consulting','Designing' ,'Testing','Infrastructure','Data, AI & ML','Other'], loc = 'lower right')

plt.grid()

# %%
import matplotlib.pyplot as plt
my_range = range (0, len(df))
plt.hlines(y=df['Vị trí'], xmin=0, xmax=df['Từ 3 đến dưới 5 năm'], color=my_color,linewidth=3, alpha =0.8)
plt.scatter(df['Từ 3 đến dưới 5 năm'], my_range, color=my_color, s=80, alpha=1)
plt.title(" Từ 3 đến dưới 5 năm  ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xlabel('Lương (triệu)', fontsize=10)
plt.ylabel('',fontsize=20)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

# %%
import matplotlib.pyplot as plt
my_range = range (0, len(df))
plt.hlines(y=df['Vị trí'], xmin=0, xmax=df['Từ 5 đến 8 năm'], color=my_color,linewidth=3, alpha =0.8)
plt.scatter(df['Từ 5 đến 8 năm'], my_range, color=my_color, s=80, alpha=1)
plt.title("Từ 5 đến 8 năm  ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xlabel('Lương (triệu)', fontsize=10)
plt.ylabel('',fontsize=20)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
plt.grid()

# %%
import matplotlib.pyplot as plt
my_range = range (0, len(df))
plt.hlines(y=df['Vị trí'], xmin=0, xmax=df['Trên 8 năm'], color=my_color,linewidth=3, alpha =0.8)
plt.scatter(df['Trên 8 năm'], my_range, color=my_color, s=80, alpha=1)
plt.title(" Trên 8 năm	  ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xlabel('Lương (triệu)', fontsize=10)
plt.ylabel('',fontsize=20)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
plt.grid()
# Out:
# /Users/thutranghoa/Library/Python/3.9/lib/python/site-packages/IPython/core/events.py:93: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /Users/thutranghoa/Library/Python/3.9/lib/python/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Cách 1 : Dùng biểu đồ linechart
#
# - Dựa vào biểu đồ linechart, ta sẽ thấy được với từng nhóm ngành, mức độ tăng trưởng thu nhập theo năm kinh nghiệm là bao nhiêu
# - Đồng thời, với từng nhóm ngành, ta cũng biết được mức lương tại từng năm kinh nghiệm của từng vị trí

# %%
import matplotlib.pyplot as plt 
from matplotlib.pyplot import figure

from matplotlib.lines import Line2D

fig = plt.gcf()
fig.set_size_inches(18, 50)
width = 0.4
plt.subplot(4,2,1)
sns.lineplot(x=df_transpose.index, y='Back-end Developer', data=df_transpose, marker='o', color='#ffa600', label='Back-end Developer')
sns.lineplot(x=df_transpose.index, y='Front-end Developer', data=df_transpose, marker='o', color='#f95d6a', label='Front-end Developer')
sns.lineplot(x=df_transpose.index, y='Full-stack Developer', data=df_transpose, marker='o', color='darkcyan', label='Full-stack Developer')
sns.lineplot(x=df_transpose.index, y='Mobile Developer', data=df_transpose, marker='o', color='blue', label='Mobile Developer')
sns.lineplot(x=df_transpose.index, y='Game Developer', data=df_transpose, marker='o', color='green', label='Game Developer')
sns.lineplot(x=df_transpose.index, y='Embedded Engineer', data=df_transpose, marker='o', color='#a05195', label='Embedded Engineer')
plt.ylabel('Lương (triệu)',fontsize=13)
plt.title(" Software Development ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks([])
plt.xlabel('')


plt.grid()

plt.subplot(4,2,2)
sns.lineplot(x=df_transpose.index, y='Product Owner/Product Manager/ Business Analyst', data=df_transpose, marker='o', color='navy', label='Product Owner/Product Manager/ Business Analyst')
plt.ylabel('Lương (triệu)',fontsize=13)
plt.title(" Product Manager ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks([])
plt.xlabel('')
plt.grid()


plt.subplot(4,2,3)
sns.lineplot(x=df_transpose.index, y='Project Manager/Project Leader', data=df_transpose, marker='o', color='#ffa600', label='Project Manager/Project Leader')

sns.lineplot(x=df_transpose.index, y='IT Lead/Manager', data=df_transpose, marker='o', color='purple', label='IT Lead/Manager')

sns.lineplot(x=df_transpose.index, y='IT Consultant', data=df_transpose, marker='o', color='navy', label='IT Consultant')

plt.ylabel('Lương (triệu)',fontsize=13)
plt.title(" Management & Consulting ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks([])
plt.xlabel('')
plt.grid()


plt.subplot(4,2,4)
sns.lineplot(x=df_transpose.index, y='Designer', data=df_transpose, marker='o', color='green', label='Designer')


plt.ylabel('Lương (triệu)',fontsize=13)
plt.title(" Designing ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks([])
plt.xlabel('')
plt.grid()


plt.subplot(4,2,5)

sns.lineplot(x=df_transpose.index, y='Tester or QA-QC', data=df_transpose, marker='o', color='darkcyan', label='Tester or QA-QC')


plt.ylabel('Lương (triệu)',fontsize=13)
plt.title(" Testing ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks([])
plt.xlabel('')
plt.grid()


plt.subplot(4,2,6)
sns.lineplot(x=df_transpose.index, y='System Engineer/System Admin', data=df_transpose, marker='o', color='#ffa600', label='System Engineer/System Admin')

sns.lineplot(x=df_transpose.index, y='DevOps Engineer', data=df_transpose, marker='o', color='navy', label='DevOps Engineer')
plt.ylabel('Lương (triệu)',fontsize=13)
plt.title(" Infrastructure ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks([])
plt.xlabel('')
plt.grid()


plt.subplot(4,2,7)
sns.lineplot(x=df_transpose.index, y='Chuyen gia Data, AI & ML', data=df_transpose, marker='o', color='blue', label='Chuyen gia Data, AI & ML')


plt.title(" Data, AI & ML ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks(rotation = 50)
plt.xlabel('')
plt.grid()


plt.subplot(4,2,8)
sns.lineplot(x=df_transpose.index, y='ERP Engineer/ERP Consultant', data=df_transpose, marker='o', color='purple', label='ERP Engineer/ERP Consultant')

sns.lineplot(x=df_transpose.index, y='Solution Architect', data=df_transpose, marker='o', color='tomato', label='Solution Architect')
plt.ylabel('Lương (triệu)',fontsize=13)
plt.title(" Other ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks(rotation = 50)
plt.xlabel('')
plt.grid()


fig.savefig('lineplot.png', dpi=400)

# %%
import seaborn as sns

df_transpose = df.set_index('Vị trí').T
df_transpose = df_transpose.drop(index='Group')
df_transpose
# Out:
# Vị trí              Back-end Developer Front-end Developer  \
# Dưới 1 năm                        12.0                11.0
# Từ 1 đến dưới 3 năm               18.0                15.0
# Từ 3 đến dưới 5 năm               29.0                30.0
# Từ 5 đến 8 năm                    37.0                40.0
# Trên 8 năm                        49.0                70.0
#
# Vị trí              Full-stack Developer Mobile Developer Game Developer  \
# Dưới 1 năm                          17.0             12.0           19.0
# Từ 1 đến dưới 3 năm                 19.0             19.0           22.0
# Từ 3 đến dưới 5 năm                 25.0             27.0           28.5
# Từ 5 đến 8 năm                      37.0             42.0           32.0
# Trên 8 năm                          39.5             57.5           51.0
#
# Vị trí              Embedded Engineer  \
# Dưới 1 năm                       15.0
# Từ 1 đến dưới 3 năm              37.0
# Từ 3 đến dưới 5 năm               NaN
# ...

# %%
sns.lineplot(x=df_transpose.index, y='Back-end Developer', data=df_transpose, marker='o', color='#ffa600', label='Back-end Developer')
sns.lineplot(x=df_transpose.index, y='Front-end Developer', data=df_transpose, marker='o', color='#f95d6a', label='Front-end Developer')
sns.lineplot(x=df_transpose.index, y='Full-stack Developer', data=df_transpose, marker='o', color='darkcyan', label='Full-stack Developer')
sns.lineplot(x=df_transpose.index, y='Mobile Developer', data=df_transpose, marker='o', color='blue', label='Mobile Developer')
sns.lineplot(x=df_transpose.index, y='Game Developer', data=df_transpose, marker='o', color='green', label='Game Developer')
sns.lineplot(x=df_transpose.index, y='Embedded Engineer', data=df_transpose, marker='o', color='#a05195', label='Embedded Engineer')
plt.ylabel('Lương (triệu)',fontsize=13)
plt.title(" Software Development ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks(rotation = 50)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Dưới 1 năm'),
#   Text(1, 0, 'Từ 1 đến dưới 3 năm'),
#   Text(2, 0, 'Từ 3 đến dưới 5 năm'),
#   Text(3, 0, 'Từ 5 đến 8 năm'),
#   Text(4, 0, 'Trên 8 năm')])

# %%
sns.lineplot(x=df_transpose.index, y='Product Owner/Product Manager/ Business Analyst', data=df_transpose, marker='o', color='navy', label='Product Owner/Product Manager/ Business Analyst')

plt.ylabel('Lương (triệu)',fontsize=13)
plt.title(" Product Manager ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks(rotation = 50)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Dưới 1 năm'),
#   Text(1, 0, 'Từ 1 đến dưới 3 năm'),
#   Text(2, 0, 'Từ 3 đến dưới 5 năm'),
#   Text(3, 0, 'Từ 5 đến 8 năm'),
#   Text(4, 0, 'Trên 8 năm')])

# %%
sns.lineplot(x=df_transpose.index, y='Project Manager/Project Leader', data=df_transpose, marker='o', color='#ffa600', label='Project Manager/Project Leader')

sns.lineplot(x=df_transpose.index, y='IT Lead/Manager', data=df_transpose, marker='o', color='purple', label='IT Lead/Manager')

sns.lineplot(x=df_transpose.index, y='IT Consultant', data=df_transpose, marker='o', color='navy', label='IT Consultant')

plt.ylabel('Lương (triệu)',fontsize=13)
plt.title(" Management & Consulting ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks(rotation = 50)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Dưới 1 năm'),
#   Text(1, 0, 'Từ 1 đến dưới 3 năm'),
#   Text(2, 0, 'Từ 3 đến dưới 5 năm'),
#   Text(3, 0, 'Từ 5 đến 8 năm'),
#   Text(4, 0, 'Trên 8 năm')])

# %%
sns.lineplot(x=df_transpose.index, y='Designer', data=df_transpose, marker='o', color='green', label='Designer')


plt.ylabel('Lương (triệu)',fontsize=13)
plt.title(" Designing ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks(rotation = 50)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Dưới 1 năm'),
#   Text(1, 0, 'Từ 1 đến dưới 3 năm'),
#   Text(2, 0, 'Từ 3 đến dưới 5 năm'),
#   Text(3, 0, 'Từ 5 đến 8 năm'),
#   Text(4, 0, 'Trên 8 năm')])

# %%
sns.lineplot(x=df_transpose.index, y='Tester or QA-QC', data=df_transpose, marker='o', color='darkcyan', label='Tester or QA-QC')


plt.ylabel('Lương (triệu)',fontsize=13)
plt.title(" Testing ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks(rotation = 50)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Dưới 1 năm'),
#   Text(1, 0, 'Từ 1 đến dưới 3 năm'),
#   Text(2, 0, 'Từ 3 đến dưới 5 năm'),
#   Text(3, 0, 'Từ 5 đến 8 năm'),
#   Text(4, 0, 'Trên 8 năm')])

# %%
sns.lineplot(x=df_transpose.index, y='System Engineer/System Admin', data=df_transpose, marker='o', color='#ffa600', label='System Engineer/System Admin')

sns.lineplot(x=df_transpose.index, y='DevOps Engineer', data=df_transpose, marker='o', color='navy', label='DevOps Engineer')
plt.ylabel('Lương (triệu)',fontsize=13)
plt.title(" Infrastructure ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks(rotation = 50)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Dưới 1 năm'),
#   Text(1, 0, 'Từ 1 đến dưới 3 năm'),
#   Text(2, 0, 'Từ 3 đến dưới 5 năm'),
#   Text(3, 0, 'Từ 5 đến 8 năm'),
#   Text(4, 0, 'Trên 8 năm')])

# %%
sns.lineplot(x=df_transpose.index, y='Chuyen gia Data, AI & ML', data=df_transpose, marker='o', color='blue', label='Chuyen gia Data, AI & ML')


plt.title(" Data, AI & ML ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks(rotation = 50)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Dưới 1 năm'),
#   Text(1, 0, 'Từ 1 đến dưới 3 năm'),
#   Text(2, 0, 'Từ 3 đến dưới 5 năm'),
#   Text(3, 0, 'Từ 5 đến 8 năm'),
#   Text(4, 0, 'Trên 8 năm')])

# %%
sns.lineplot(x=df_transpose.index, y='ERP Engineer/ERP Consultant', data=df_transpose, marker='o', color='purple', label='ERP Engineer/ERP Consultant')

sns.lineplot(x=df_transpose.index, y='Solution Architect', data=df_transpose, marker='o', color='tomato', label='Solution Architect')
plt.ylabel('Lương (triệu)',fontsize=13)
plt.title(" Other ", fontsize=12, x=0.5,y=1.02,color = 'red')
plt.xticks(rotation = 50)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Dưới 1 năm'),
#   Text(1, 0, 'Từ 1 đến dưới 3 năm'),
#   Text(2, 0, 'Từ 3 đến dưới 5 năm'),
#   Text(3, 0, 'Từ 5 đến 8 năm'),
#   Text(4, 0, 'Trên 8 năm')])
